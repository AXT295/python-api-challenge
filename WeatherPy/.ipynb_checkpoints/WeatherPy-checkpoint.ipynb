# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 591

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']  
        city_clouds = city_weather['clouds']['all'] 
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country'] 
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chibougamau
# Processing Record 2 of Set 1 | shakawe
# Processing Record 3 of Set 1 | stanley
# Processing Record 4 of Set 1 | el porvenir
# Processing Record 5 of Set 1 | abepura
# Processing Record 6 of Set 1 | vila franca do campo
# Processing Record 7 of Set 1 | sibiti
# Processing Record 8 of Set 1 | nuku'alofa
# Processing Record 9 of Set 1 | santa ana
# Processing Record 10 of Set 1 | pimentel
# Processing Record 11 of Set 1 | punta del este
# Processing Record 12 of Set 1 | wailua homesteads
# Processing Record 13 of Set 1 | malango
# Processing Record 14 of Set 1 | grytviken
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | meadow lake
# Processing Record 17 of Set 1 | tura
# Processing Record 18 of Set 1 | iqaluit
# Processing Record 19 of Set 1 | cimahi
# Processing Record 20 of Set 1 | bethel
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | yorkton
# Processing Record 23 of Set 1 | thompson
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | nadym
# Processing Record 26 of Set 1 | parintins
# Processing Record 27 of Set 1 | port-aux-francais
# Processing Record 28 of Set 1 | otaru
# Processing Record 29 of Set 1 | puerto natales
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | labytnangi
# Processing Record 32 of Set 1 | edinburgh of the seven seas
# Processing Record 33 of Set 1 | alice springs
# Processing Record 34 of Set 1 | olonkinbyen
# Processing Record 35 of Set 1 | bargara
# City not found. Skipping...
# Processing Record 36 of Set 1 | mugia
# Processing Record 37 of Set 1 | nova xavantina
# Processing Record 38 of Set 1 | cabo san lucas
# Processing Record 39 of Set 1 | torbat-e jam
# Processing Record 40 of Set 1 | andergrove
# Processing Record 41 of Set 1 | savanna-la-mar
# Processing Record 42 of Set 1 | saldanha
# Processing Record 43 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 44 of Set 1 | qaqortoq
# Processing Record 45 of Set 1 | port-vila
# Processing Record 46 of Set 1 | val-d'or
# Processing Record 47 of Set 1 | kitimat
# Processing Record 48 of Set 1 | amursk
# Processing Record 49 of Set 1 | haimen
# Processing Record 50 of Set 1 | ushuaia
# Processing Record 0 of Set 2 | papatowai
# Processing Record 1 of Set 2 | waitangi
# Processing Record 2 of Set 2 | enewetak
# Processing Record 3 of Set 2 | margaret river
# Processing Record 4 of Set 2 | hawaiian paradise park
# Processing Record 5 of Set 2 | uturoa
# Processing Record 6 of Set 2 | west island
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | mahibadhoo
# Processing Record 9 of Set 2 | tiksi
# Processing Record 10 of Set 2 | adamstown
# Processing Record 11 of Set 2 | port macquarie
# Processing Record 12 of Set 2 | bilibino
# Processing Record 13 of Set 2 | alofi
# Processing Record 14 of Set 2 | north side
# Processing Record 15 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 16 of Set 2 | island harbour
# Processing Record 17 of Set 2 | kavieng
# Processing Record 18 of Set 2 | isafjordur
# Processing Record 19 of Set 2 | chonchi
# Processing Record 20 of Set 2 | tucurui
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | jamestown
# Processing Record 23 of Set 2 | olyokminsk
# Processing Record 24 of Set 2 | hithadhoo
# Processing Record 25 of Set 2 | saint-pierre
# Processing Record 26 of Set 2 | sao tome
# Processing Record 27 of Set 2 | antalaha
# Processing Record 28 of Set 2 | guerrero negro
# Processing Record 29 of Set 2 | kourou
# Processing Record 30 of Set 2 | cole harbour
# Processing Record 31 of Set 2 | dudinka
# Processing Record 32 of Set 2 | ca mau
# Processing Record 33 of Set 2 | tosontsengel
# Processing Record 34 of Set 2 | greenville
# Processing Record 35 of Set 2 | okhotsk
# Processing Record 36 of Set 2 | san vicente
# Processing Record 37 of Set 2 | buka
# Processing Record 38 of Set 2 | coquimbo
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | puerto baquerizo moreno
# Processing Record 41 of Set 2 | ilulissat
# Processing Record 42 of Set 2 | general conesa
# Processing Record 43 of Set 2 | nizhneangarsk
# Processing Record 44 of Set 2 | papao
# Processing Record 45 of Set 2 | ribeira grande
# Processing Record 46 of Set 2 | keflavik
# Processing Record 47 of Set 2 | coro
# Processing Record 48 of Set 2 | kelibia
# Processing Record 49 of Set 2 | thinadhoo
# Processing Record 0 of Set 3 | tabou
# Processing Record 1 of Set 3 | ketchikan
# Processing Record 2 of Set 3 | robertsport
# Processing Record 3 of Set 3 | skovorodino
# Processing Record 4 of Set 3 | codrington
# Processing Record 5 of Set 3 
# Processing Record 36 of Set 4 | hamilton
# Processing Record 37 of Set 4 | caleta de carquin
# Processing Record 38 of Set 4 | la passe
# Processing Record 39 of Set 4 | badger
# Processing Record 40 of Set 4 | anadyr
# Processing Record 41 of Set 4 | porto novo
# Processing Record 42 of Set 4 | la'ie
# Processing Record 43 of Set 4 | nuuk
# Processing Record 44 of Set 4 | machico
# Processing Record 45 of Set 4 | whitehorse
# Processing Record 46 of Set 4 | haiku-pauwela
# Processing Record 47 of Set 4 | antofagasta
# Processing Record 48 of Set 4 | kununurra
# Processing Record 49 of Set 4 | sakaiminato
# Processing Record 0 of Set 5 | kristinestad
# Processing Record 1 of Set 5 | chul'man
# Processing Record 2 of Set 5 | gazojak
# Processing Record 3 of Set 5 | chos malal
# Processing Record 4 of Set 5 | bandarbeyla
# Processing Record 5 of Set 5 | es castell
# Processing Record 6 of Set 5 | nizhneudinsk
# Processing Record 7 of Set 5 | lazaro cardenas
# Processing Record 8 of Set 5 | afaahiti
# Processing Record 9 of Set 5 | praia da vitoria
# Processing Record 10 of Set 5 | lebu
# Processing Record 11 of Set 5 | chingola
# Processing Record 12 of Set 5 | zakynthos
# Processing Record 13 of Set 5 | nemuro
# Processing Record 14 of Set 5 | cadale
# Processing Record 15 of Set 5 | whangarei
# Processing Record 16 of Set 5 | crane
# Processing Record 17 of Set 5 | nar'yan-mar
# Processing Record 18 of Set 5 | buala
# Processing Record 19 of Set 5 | chuguyevka
# Processing Record 20 of Set 5 | yanji
# Processing Record 21 of Set 5 | chato
# Processing Record 22 of Set 5 | natal
# Processing Record 23 of Set 5 | wenling
# Processing Record 24 of Set 5 | mukah
# City not found. Skipping...
# Processing Record 25 of Set 5 | road town
# Processing Record 26 of Set 5 | st. john's
# Processing Record 27 of Set 5 | georgetown
# Processing Record 28 of Set 5 | kapuskasing
# Processing Record 29 of Set 5 | howard springs
# Processing Record 30 of Set 5 | sint michiel liber
# Processing Record 31 of Set 5 | tazovsky
# Processing Record 32 of Set 5 | naze
# Processing Record 33 of Set 5 | penal
# Processing Record 34 of Set 5 | nantucket
# Processing Record 35 of Set 5 | toamasina
# Processing Record 36 of Set 5 | al ghayzah
# Processing Record 37 of Set 5 | broome
# Processing Record 38 of Set 5 | revda
# Processing Record 39 of Set 5 | castillos
# Processing Record 40 of Set 5 | puerto carreno
# Processing Record 41 of Set 5 | vernon
# Processing Record 42 of Set 5 | losice
# Processing Record 43 of Set 5 | paragominas
# Processing Record 44 of Set 5 | okha
# Processing Record 45 of Set 5 | udachny
# Processing Record 46 of Set 5 | mariental
# Processing Record 47 of Set 5 | pisco
# Processing Record 48 of Set 5 | fort st. john
# Processing Record 49 of Set 5 | birjand
# Processing Record 0 of Set 6 | bamboo flat
# Processing Record 1 of Set 6 | kapa'a
# Processing Record 2 of Set 6 | vytegra
# Processing Record 3 of Set 6 | korhogo
# Processing Record 4 of Set 6 | invercargill
# Processing Record 5 of Set 6 | kailua-kona
# Processing Record 6 of Set 6 | pingliang
# Processing Record 7 of Set 6 | cannonvale
# Processing Record 8 of Set 6 | dolores
# Processing Record 9 of Set 6 | aasiaat
# Processing Record 10 of Set 6 | quthing
# Processing Record 11 of Set 6 | vilyuchinsk
# Processing Record 12 of Set 6 | tofol
# Processing Record 13 of Set 6 | the pas
# Processing Record 14 of Set 6 | ahau
# City not found. Skipping...
# Processing Record 15 of Set 6 | pasni
# Processing Record 16 of Set 6 | howrah
# Processing Record 17 of Set 6 | liepaja
# Processing Record 18 of Set 6 | fannuj
# City not found. Skipping...
# Processing Record 19 of Set 6 | kosice
# Processing Record 20 of Set 6 | brak
# Processing Record 21 of Set 6 | mizdah
# Processing Record 22 of Set 6 | ostrow wielkopolski
# Processing Record 23 of Set 6 | hilo
# Processing Record 24 of Set 6 | sinabang
# Processing Record 25 of Set 6 | hadibu
# Processing Record 26 of Set 6 | saint-philippe
# Processing Record 27 of Set 6 | kodinsk
# Processing Record 28 of Set 6 | batang
# Processing Record 29 of Set 6 | aksu
# Processing Record 30 of Set 6 | ballina
# Processing Record 31 of Set 6 | moroni
# Processing Record 32 of Set 6 | susuman
# Processing Record 33 of Set 6 | tarfaya
# Processing Record 34 of Set 6 | abay
# Processing Record 35 of Set 6 | sitka
# Processing Record 36 of Set 6 | tabua
# Processing Record 37 of Set 6 | kananga
# Processing Record 38 of Set 6 | atafu village
# Processing Record 39 of Set 6 | siwa oasis
# Processing Record 40 of Set 6 | bobrov
# Processing Record 41 of Set 6 | ambodifotatra
# Processing Record 42 of Set 6 | mount pearl
# Processing Record 43 of Set 6 | nagqu
# Processing Record 44 of Set 6 | las tablas
# Processing Record 45 of Set 6 | ayr
# Processing Record 46 of Set 6 | sorong
# Processing Record 47 of Set 6 | sinjai
# Processing Record 48 of Set 6 | ugoofaaru
# Processing Record 49 of Set 6 | san fernando de apure
# Processing Record 0 of Set 7 | sovetskaya gavan'
# Processing Record 1 of Set 7 | klaksvik
# Processing Record 2 of Set 7 | billings
# Processing Record 3 of Set 7 | qui nhon
# Processing Record 4 of Set 7 | fale old settlement
# Processing Record 5 of Set 7 | yeppoon city centre
# City not found. Skipping...
# Processing Record 6 of Set 7 | childress
# Processing Record 7 of Set 7 | sedalia
# Processing Record 8 of Set 7 | zykovo
# Processing Record 9 of Set 7 | bayan nur
# City not found. Skipping...
# Processing Record 10 of Set 7 | callao
# Processing Record 11 of Set 7 | norilsk
# Processing Record 12 of Set 7 | gaiman
# Processing Record 13 of Set 7 | labuan bajo
# Processing Record 14 of Set 7 | katsuren-haebaru
# Processing Record 15 of Set 7 | namibe
# Processing Record 16 of Set 7 | pakxan
# Processing Record 17 of Set 7 | lewistown
# Processing Record 18 of Set 7 | arraial do cabo
# Processing Record 19 of Set 7 | sidney
# Processing Record 20 of Set 7 | yuzhno-kurilsk
# Processing Record 21 of Set 7 | villa zempoala
# Processing Record 22 of Set 7 | am djarass
# City not found. Skipping...
# Processing Record
# Processing Record 47 of Set 8 | barcelos
# Processing Record 48 of Set 8 | molochnoye
# Processing Record 49 of Set 8 | chios
# Processing Record 0 of Set 9 | ajaokuta
# Processing Record 1 of Set 9 | lastoursville
# Processing Record 2 of Set 9 | port saint john's
# Processing Record 3 of Set 9 | mentor-on-the-lake
# Processing Record 4 of Set 9 | pangody
# Processing Record 5 of Set 9 | richards bay
# Processing Record 6 of Set 9 | karystos
# Processing Record 7 of Set 9 | hoemul-li
# Processing Record 8 of Set 9 | skikda
# Processing Record 9 of Set 9 | barah
# Processing Record 10 of Set 9 | ajdabiya
# Processing Record 11 of Set 9 | airway heights
# Processing Record 12 of Set 9 | inhambane
# Processing Record 13 of Set 9 | xichang
# Processing Record 14 of Set 9 | flin flon
# Processing Record 15 of Set 9 | deqen
# Processing Record 16 of Set 9 | san luis de la loma
# Processing Record 17 of Set 9 | smara
# Processing Record 18 of Set 9 | saint-francois
# Processing Record 19 of Set 9 | montepuez
# Processing Record 20 of Set 9 | kingston
# Processing Record 21 of Set 9 | north fort myers
# Processing Record 22 of Set 9 | fabens
# Processing Record 23 of Set 9 | walvis bay
# Processing Record 24 of Set 9 | santana
# Processing Record 25 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 26 of Set 9 | timbuktu
# Processing Record 27 of Set 9 | raduzhny
# Processing Record 28 of Set 9 | mafeteng
# Processing Record 29 of Set 9 | ratangarh
# Processing Record 30 of Set 9 | severo-yeniseyskiy
# Processing Record 31 of Set 9 | malindi
# Processing Record 32 of Set 9 | raton
# Processing Record 33 of Set 9 | arnprior
# Processing Record 34 of Set 9 | nguigmi
# Processing Record 35 of Set 9 | kuytun
# Processing Record 36 of Set 9 | burdur
# Processing Record 37 of Set 9 | harper
# Processing Record 38 of Set 9 | hazro city
# Processing Record 39 of Set 9 | pundong
# Processing Record 40 of Set 9 | ola
# Processing Record 41 of Set 9 | justo daract
# Processing Record 42 of Set 9 | kargasok
# Processing Record 43 of Set 9 | norten-hardenberg
# Processing Record 44 of Set 9 | mudgee
# Processing Record 45 of Set 9 | dauphin
# Processing Record 46 of Set 9 | el vigia
# Processing Record 47 of Set 9 | jodhpur
# Processing Record 48 of Set 9 | gardez
# Processing Record 49 of Set 9 | zyrya
# Processing Record 0 of Set 10 | heishan
# Processing Record 1 of Set 10 | nizhniy kuranakh
# Processing Record 2 of Set 10 | shimanovsk
# Processing Record 3 of Set 10 | salaberry-de-valleyfield
# Processing Record 4 of Set 10 | sept-iles
# Processing Record 5 of Set 10 | touba
# Processing Record 6 of Set 10 | anna regina
# Processing Record 7 of Set 10 | maevatanana
# City not found. Skipping...
# Processing Record 8 of Set 10 | constitucion
# Processing Record 9 of Set 10 | veraval
# Processing Record 10 of Set 10 | suez
# Processing Record 11 of Set 10 | bouarfa
# Processing Record 12 of Set 10 | moundou
# Processing Record 13 of Set 10 | dharamsala
# Processing Record 14 of Set 10 | itaituba
# Processing Record 15 of Set 10 | jinja
# Processing Record 16 of Set 10 | tubarjal
# Processing Record 17 of Set 10 | trinidad
# Processing Record 18 of Set 10 | beitbridge
# Processing Record 19 of Set 10 | huicungo
# Processing Record 20 of Set 10 | fort bragg
# Processing Record 21 of Set 10 | nkurenkuru
# City not found. Skipping...
# Processing Record 22 of Set 10 | krasnozerskoye
# Processing Record 23 of Set 10 | boa vista
# Processing Record 24 of Set 10 | kita
# Processing Record 25 of Set 10 | lawas
# Processing Record 26 of Set 10 | goondiwindi
# Processing Record 27 of Set 10 | paranagua
# Processing Record 28 of Set 10 | mwatate
# Processing Record 29 of Set 10 | nelson bay
# Processing Record 30 of Set 10 | port hedland
# Processing Record 31 of Set 10 | tual
# Processing Record 32 of Set 10 | brisas de zicatela
# Processing Record 33 of Set 10 | charcas
# Processing Record 34 of Set 10 | usoke
# Processing Record 35 of Set 10 | mitu
# Processing Record 36 of Set 10 | port lincoln
# Processing Record 37 of Set 10 | fortuna
# Processing Record 38 of Set 10 | khorugh
# Processing Record 39 of Set 10 | gulf breeze
# Processing Record 40 of Set 10 | aberdeen
# Processing Record 41 of Set 10 | coahuayana de hidalgo
# Processing Record 42 of Set 10 | fortaleza
# Processing Record 43 of Set 10 | santa rosa
# Processing Record 44 of Set 10 | aleksandrovsk-sakhalinskiy
# Processing Record 45 of Set 10 | shingu
# Processing Record 46 of Set 10 | san julian
# Processing Record 47 of Set 10 | mandalgovi
# Processing Record 48 of Set 10 | mejit
# Processing Record 49 of Set 10 | celestun
# Processing Record 0 of Set 11 | molina
# Processing Record 1 of Set 11 | santiago del torno
# Processing Record 2 of Set 11 | thief river falls
# Processing Record 3 of Set 11 | lagos
# Processing Record 4 of Set 11 | pontianak
# Processing Record 5 of Set 11 | sergeyevka
# Processing Record 6 of Set 11 | slave lake
# Processing Record 7 of Set 11 | burang
# Processing Record 8 of Set 11 | mokrous
# Processing Record 9 of Set 11 | urucara
# Processing Record 10 of Set 11 | primero de mayo
# Processing Record 11 of Set 11 | cabagan
# Processing Record 12 of Set 11 | manavalakurichi
# Processing Record 13 of Set 11 | kivioli
# Processing Record 14 of Set 11 | ploneour-lanvern
# Processing Record 15 of Set 11 | qujing
# Processing Record 16 of Set 11 | suva
# Processing Record 17 of Set 11 | mikuni
# Processing Record 18 of Set 11 | tobelo
# Processing Record 19 of Set 11 | jamkhandi
# Processing Record 20 of Set 11 | monrovia
# Processing Record 21 of Set 11 | dunedin
# Processing Record 22 of Set 11 | gaalkacyo
# Processing Record 23 of Set 11 | ialibu
# Processing Record 24 of Set 11 | mount gambier
# Processing Record 25 of Set 11 | ingeniero jacobacci
# Processing Record 26 of Set 11 | kalach-na-donu
# Processing Record 27 of Set 11 | bapatla
# Processing Record 28 of Set 11 | luderitz
# Processing Record 29 of Set 11 | shitanjing
# Processing Record 30 of Set 11 | nizhniy ingash
# Processing Record 31 of Set 11 | ceeldheer
# Processing Record 32 of Set 11 | vorkuta
# Processing Record 33 of Set 11 | tidjikja
# Processing Record 34 of Set 11 | sisimiut
# Processing Record 35 of Set 11 | ancud
# Processing Record 36 of Set 11 | altay
# Processing Record 37 of Set 11 | checker hall
# City not found. Skipping...
# Processing Record 38 of Set 11 | veinticinco de mayo
# Processing Record 39 of Set 11 | carnarvon
# Processing Record 40 of Set 11 | nikolayevsk-on-amure
# Processing Record 41 of Set 11 | ulanhot
# Processing Record 42 of Set 11 | palmerston north
# Processing Record 43 of Set 11 | al 'alamayn
# City not found. Skipping...
# Processing Record 44 of Set 11 | lillehammer
# Processing Record 45 of Set 11 | santiago de cao
# Processing Record 46 of Set 11 | greymouth
# Processing Record 47 of Set 11 | akureyri
# Processing Record 48 of Set 11 | haapsalu
# Processing Record 49 of Set 11 | laascaanood
# Processing Record 0 of Set 12 | badiyah
# Processing Record 1 of Set 12 | amga
# Processing Record 2 of Set 12 | ambon
# Processing Record 3 of Set 12 | lata
# Processing Record 4 of Set 12 | diu
# Processing Record 5 of Set 12 | asau
# Processing Record 6 of Set 12 | vilyuysk
# Processing Record 7 of Set 12 | berezovyy
# Processing Record 8 of Set 12 | san pablo viejo abajo
# Processing Record 9 of Set 12 | pelaya
# Processing Record 10 of Set 12 | polyarnyy
# Processing Record 11 of Set 12 | silute
# Processing Record 12 of Set 12 | swift current
# Processing Record 13 of Set 12 | tommot
# Processing Record 14 of Set 12 | raiwala bara
# Processing Record 15 of Set 12 | illizi
# Processing Record 16 of Set 12 | salekhard
# Processing Record 17 of Set 12 | el calafate
# Processing Record 18 of Set 12 | rabigh
# Processing Record 19 of Set 12 | borogontsy
# Processing Record 20 of Set 12 | maturin
# Processing Record 21 of Set 12 | taybad
# Processing Record 22 of Set 12 | toyooka
# Processing Record 23 of Set 12 | chandler
# Processing Record 24 of Set 12 | tambacounda
# Processing Record 25 of Set 12 | quepos
# Processing Record 26 of Set 12 | waingapu
# Processing Record 27 of Set 12 | rwamagana
# Processing Record 28 of Set 12 | vila velha
# Processing Record 29 of Set 12 | hotan
# Processing Record 30 of Set 12 | suncho corral
# Processing Record 31 of Set 12 | muroran
# Processing Record 32 of Set 12 | palangkaraya
# Processing Record 33 of Set 12 | reggane
# Processing Record 34 of Set 12 | rasony
# Processing Record 35 of Set 12 | makueni boma
# Processing Record 36 of Set 12 | suksun
# Processing Record 37 of Set 12 | ta`u
# Processing Record 38 of Set 12 | sretensk
# Processing Record 39 of Set 12 | posto fiscal rolim de moura
# Processing Record 40 of Set 12 | holualoa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          570
# Lat           570
# Lng           570
# Max Temp      570
# Humidity      570
# Cloudiness    570
# Wind Speed    570
# Country       570
# Date          570
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  chibougamau  49.9168  -74.3659      4.79        81           0        2.06
# 1      shakawe -18.3667   21.8500     18.80        13         100        2.18
# 2      stanley  54.8680   -1.6985      9.87        89          40        3.60
# 3  el porvenir  13.7617  -87.3458     22.63        79          84        3.04
# 4      abepura  -2.6333  140.5833     31.45        58          20        1.54
#
#   Country        Date
# 0      CA  1697591015
# 1      BW  1697591015
# 2      GB  1697591015
# 3      HN  1697591015
# 4      ID  1697591015

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        chibougamau  49.9168  -74.3659      4.79        81           0
# 1            shakawe -18.3667   21.8500     18.80        13         100
# 2            stanley  54.8680   -1.6985      9.87        89          40
# 3        el porvenir  13.7617  -87.3458     22.63        79          84
# 4            abepura  -2.6333  140.5833     31.45        58          20
#
#          Wind Speed Country        Date
# City_ID
# 0              2.06      CA  1697591015
# 1              2.18      BW  1697591015
# 2              3.60      GB  1697591015
# 3              3.04      HN  1697591015
# 4              1.54      ID  1697591015

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature(C)')
plt.title('City Latitude vs.Temperature(2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.title('City Latitude vs.Humidity(2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.title('City Latitude vs.Cloudiness(2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'], marker='o', edgecolor='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(m/s)')
plt.title('City Latitude vs.Wind Speed(2022-10-18)')
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
def linear_reg(x_axis, y_axis,eq_loc):  
    correlation = st.pearsonr(x_axis,y_axis)
    p_slope, p_int, p_r, p_p, p_std_err = st.linregress(x_axis, y_axis)
    p_fit = p_slope * x_axis + p_int
    eq= f"y ={p_slope: .2f}x +{ p_int: .2f}"
       
    #Plot the line
    plt.scatter(x_axis, y_axis ,marker="o")
    plt.plot(x_axis,p_fit,"--", color='red')
    plt.annotate(eq, eq_loc, fontsize=12, color='red')
    print(f"The r-value between {x_axis.name} and {y_axis.name} is {round(correlation[0],2)}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                 chibougamau  49.9168  -74.3659      4.79        81
# 2                     stanley  54.8680   -1.6985      9.87        89
# 3                 el porvenir  13.7617  -87.3458     22.63        79
# 5        vila franca do campo  37.7167  -25.4333     21.23        99
# 8                   santa ana  33.7456 -117.8678     30.17        67
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 0        2.06      CA  1697591015
# 2                40        3.60      GB  1697591015
# 3                84        3.04      HN  1697591015
# 5               100        6.56      PT  1697591015
# 8                20        2.57      US  1697590925

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           shakawe -18.3667   21.8500     18.80        13         100
# 4           abepura  -2.6333  140.5833     31.45        58          20
# 6            sibiti  -3.6819   13.3499     21.07        97         100
# 7        nuku'alofa -21.1333 -175.2000     26.19        61          20
# 9          pimentel  -6.8367  -79.9342     21.16        78           0
#
#          Wind Speed Country        Date
# City_ID
# 1              2.18      BW  1697591015
# 4              1.54      ID  1697591015
# 6              0.75      CG  1697590941
# 7              8.75      TO  1697591015
# 9              7.72      PE  1697591016

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'],(10, -10))
plt.xlabel('Latitude')
plt.ylabel('Temperature(C)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Linear regression on Northern Hemisphere
# ----> 2 linear_reg(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'],(10, -10))
#       3 plt.xlabel('Latitude')
#       4 plt.ylabel('Temperature(C)')
#
# Cell In[13], line 2, in linear_reg(x_axis, y_axis, eq_loc)
#       1 def linear_reg(x_axis, y_axis,eq_loc):
# ----> 2     correlation = st.pearsonr(x_axis,y_axis)
#       3     p_slope, p_int, p_r, p_p, p_std_err = st.linregress(x_axis, y_axis)
#       4     p_fit = p_slope * x_axis + p_int
#
# NameError: name 'st' is not defined

# %%
# Linear regression on Southern Hemisphere
linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'],(-30, 5))
plt.xlabel('Latitude')
plt.ylabel('Temperature(C)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Linear regression on Southern Hemisphere
# ----> 2 linear_reg(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'],(-30, 5))
#       3 plt.xlabel('Latitude')
#       4 plt.ylabel('Temperature(C)')
#
# Cell In[13], line 2, in linear_reg(x_axis, y_axis, eq_loc)
#       1 def linear_reg(x_axis, y_axis,eq_loc):
# ----> 2     correlation = st.pearsonr(x_axis,y_axis)
#       3     p_slope, p_int, p_r, p_p, p_std_err = st.linregress(x_axis, y_axis)
#       4     p_fit = p_slope * x_axis + p_int
#
# NameError: name 'st' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
